# %% [markdown]
# # Jupyter notebook for creating figure1.png

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os
os.chdir("../../")

# %%
data = pd.read_csv("data/2020-01/mtcars.csv")

# %%
plt.scatter(data.hp, data.mpg)
plt.title("Figure 1 - correlation of two variables in mtcars dataset")
plt.xlabel("hp")
plt.ylabel("mpg")
plt.savefig("results/2020-01/figure1.png")
